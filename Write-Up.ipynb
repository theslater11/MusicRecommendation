# %% [markdown]
# ##### Which insights did you gain from your EDA? Were any columns highly correlated? If so, name them.
#
# The first coorelation that was identified was the relationship between the 'age' column and the 'release_date' column. When plotted, they were exactly identical, meaning that only one of these columns needed to be kept. The second correlations were found when we looked at the means of the lyrical content columns against our catagorical variable. It showed that the catagorical topics given to each song were identical to the lyrical content columns that deviated furthest positvely from the mean. This showed that our topic columns would be represnted within the data itself and was not necessary.

# %% [markdown]
# ##### How did you determine which columns to drop or keep? If your EDA informed this process, explain which insights you used to determine which columns were not needed.
#
# My EDA helped me decide which columns to keep and drop by showing me key insights. First was to remove unique indentifiers like track_name and lyrics, since the content of the lyrics had already been evaluated. I then compared the release_date & age column, finding that they are identical. I chose to keep the standardized age column and drop the release_date column. I then looke at the lyrical content columns and found that none of them had full coorelation with another column. This meant I must keep all of these columns. Next, when evaluating the 'len' column, there seemed to be Finally, I looked into the rest of the catagorical columns, finding that 'artist_name' was encompessed almost entirely within 'genre' meaning it could be dropped while genre could be kept and encoded. In modeling stage however, it was determined necessary to drop the genre column due to over=representation

# %% [markdown]
# ##### What was the optimal number of clusters in your cluster model? Explain how you determined this value.
#
# My Kmeans model and Hierchacal Clustering model came to similar conclusions. The Kmeans model produced an elbow plot suggesting optimal number of clusters is 6 Optimal is not always the best choice depending on use case, however. The dendrogram produced by my hierarchal model showed that there was another cut to be made just after that increases my clusters to 10, while maintaining volume and integrity in each cluster. This let our model do a better job providing the user with a song closer resembling their taste.

# %% [markdown]
# ##### Take a look at the respective songs that fell into your clusters. Describe these clusters in human terms to the best of your ability using the columns in your dataset (for example high-gospel songs, low-gospel songs, etc). Feel free to listen to these songs as well to get a sense of what nuance your algorithm picked up on.
#
# The conclusion of my model goes much more in depth about the breakdown of some nuance, but this is a brief breakdown. Most of the clusters were defined by a single standout catagory.
#
#
#
# Cluster 1: Parental Advisory. Heavy themes of violence. Probably includes most hard rock.
#
# Cluster 2: Songs of the Night. Heavy themes of night/time. Who knew how popular the moon and stars were in songwriting? Get a new metaphor!
#
# Clusters 3: Music Music. Songs whose content talks about music itself. Listen to a songwriters personal therapy.
#
# Cluster 4: Love Songs. High in romance, low in sadness. Love in its purest form is an artwork. That being said I would disintigrate from pure cringe if any love songs I wrote were ever released. Good on these artists.
#
# Cluster 5 old, sad songs. The classics that made your parents cry. Maybe. They are pretty old. The songs, not your parents.. Uh, scored highly in sadness and highly in age (older).
#
# Cluster 6 is new, sad songs. Scored highly in sadness and low in age (younger). Listen to think about your most devistating and vulnerable moments :D
#
# Cluster 7 is ... a mystery. songs high in obsentiy that also score high in age. Kenny Rodgers - Gambler type stuff maybe? Possibly do-wop or greaser? Isn't obsenity a subjective measure that has changed over time? This is a playlist for risk-takers.
#
# Clusters 8: Songs of our modern world. high-world life content with low age (younger). Oh man, this cluster is about to POP. Get it? Cause it's pop music? Yeah, I don't get it either.
#
# Cluster 9: The good ole' days. high-world life content with high age (older). This will teach you the lessons your parents never taught you.
#
# Cluster 10 is younger, obsene songs.  This is the home of most hip-hop and reggae.

# %% [markdown]
# ##### Take a look at the clusters that your algorithm assigned to your test samples. Based on these clusters, which songs would you recommend to this user?
#
# Our clustering model performed the best, so those labels will be the ones I choose.
#
# Three songs were classified as violent, the most of any catagory, Rage Against the Machine was correctly classified as high in obsenity, but is also probably a bit violent. Godsmack is also not included in either of those. It is safe to say that upbeat, hard rock is what they are looking for and clusters 0 and cluster 7 will likely provide that.
