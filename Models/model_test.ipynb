# %% [markdown]
# # Test Model

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/sa12/Documents/Repositories/MusicReccomendation/MusicRecommendation/Data/train.csv')
hc_labels = pd.read_csv('/Users/sa12/Documents/Repositories/MusicReccomendation/MusicRecommendation/Data/HC_labels.csv')

# %%
#create df for desired output.
data['labels'] = hc_labels['labels']
data = data[['artist_name', 'track_name','genre','labels']]
data
# Out:
#                 artist_name                     track_name    genre  labels
# 0                    mukesh           mohabbat bhi jhoothi      pop       4
# 1             frankie laine                      i believe      pop       8
# 2               johnnie ray                            cry      pop       2
# 3               pérez prado                       patricia      pop       4
# 4      giorgos papadopoulos             apopse eida oneiro      pop       8
# ...                     ...                            ...      ...     ...
# 28357               mack 10                10 million ways  hip hop       9
# 28358                m.o.p.  ante up (robbin hoodz theory)  hip hop       9
# 28359                  nine                  whutcha want?  hip hop       9
# 28360            will smith                         switch  hip hop       9
# 28361                 jeezy                         r.i.p.  hip hop       9
#
# [28362 rows x 4 columns]

# %%
#choose a cluster 0-9
sample = data[data['labels'] == 0]
#how many recommendations to provide
sample.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #choose a cluster 0-9
# ----> 2 sample = data[data['labels'] == 0]
#       3 #how many recommendations to provide
#       4 sample.sample(5)
#
# NameError: name 'data' is not defined

# %% [markdown]
# Cluster 0: Parental Advisory. Heavy themes of violence.
#
# Cluster 1: Songs of the Night. :F
#
# Clusters 2: Music Music. Listen to a songwriters personal therapy.
#
# Cluster 3: Love Songs. Love in its purest form is an artwork. That being said I would disintigrate from pure cringe if any love songs I wrote were ever released. Good on these artists.
#
# Cluster 4 old, sad songs. The classics that made your parents cry. Maybe. They are pretty old. The songs, not your parents.
#
# Cluster 5 is new, sad songs. Listen to think about your most devistating and vulnerable moments :D
#
# Cluster 6 is ... a mystery. songs high in obsentiy that also score high in age. Kenny Rodgers - Gambler type stuff maybe? Possibly do-wop or greaser? Isn't obsenity a subjective measure that has changed over time? This is a playlist for risk-takers.
#
# Clusters 7: Songs of our modern world. Oh man, this cluster is about to POP. Get it? Cause it's pop music? Yeah, I don't get it either.
#
# Cluster 8: The good ole' days. This will teach you the lessons your parents never taught you.
#
# Cluster 9 home of most hip-hop and reggae.
