# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/sa12/Documents/Repositories/MusicReccomendation/MusicRecommendation/Data/train.csv')
kmeans_labels = pd.read_csv('/Users/sa12/Documents/Repositories/MusicReccomendation/MusicRecommendation/Data/kmeans_labels.csv')
hc_labels = pd.read_csv('/Users/sa12/Documents/Repositories/MusicReccomendation/MusicRecommendation/Data/HC_labels.csv')

# %%
test_data

# %%
kmeans_labels = kmeans_labels.drop(columns='Unnamed: 0')
data['labels'] = kmeans_labels

# %%
data2 = data2[['artist_name', 'track_name', 'labels']]
sample = data2[data2['labels'] == 3]
sample.sample(5)
